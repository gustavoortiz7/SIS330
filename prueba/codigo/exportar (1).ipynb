# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2  Python-3.8.3 torch-2.2.2+cpu CPU (AMD Ryzen 5 PRO 5650U with Radeon Graphics)
# Setup complete  (12 CPUs, 15.3 GB RAM, 202.5/476.2 GB disk)

# %%
import torch
from ultralytics import YOLO

# Cargar el modelo YOLOv8 Pose versión small
model = YOLO('C:\\EV\\yolov8s-pose_saved_model\\yolov8s-pose_float32.tflite')  # Reemplaza con la ruta a tu modelo si es diferente
results = model.track("https://ultralytics.com/images/bus.jpg")
# Out:
# Loading C:\EV\yolov8s-pose_saved_model\yolov8s-pose_float32.tflite for TensorFlow Lite inference...
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\EV\PROYECTO\bus.jpg: 640x640 4 persons, 730.8ms
# Speed: 4.0ms preprocess, 730.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
img="C:\\EV\\PROYECTO\\bus.jpg"
image = cv2.imread(img)
#target_size = (640, 640)
#resized_image = cv2.resize(image, target_size)
annotated_frame = results[0].plot()
cv2.imshow('Resized Image', annotated_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO('E:\yolov8DeteccionBilletes\\runs\detect\\train\weights\\best.pt')  # load a custom trained model

# Export the model
#model.export(format='tflite', imgz=320)

# !yolo export model='/content/drive/MyDrive/Poyecto-IA3/models/best1.pt' format=tflite imgsz=320
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Poyecto-IA3/models/best1.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 7, 2100) (21.5 MB)
# 2024-05-14 03:56:21.779423: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 03:56:21.779494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 03:56:21.781201: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
